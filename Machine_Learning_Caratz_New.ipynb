# %% [markdown]
# <a href="https://colab.research.google.com/github/keylishaa/ML_ProjectAkhir/blob/main/Machine_Learning_Caratz_New.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **7.2.1 Melakukan overview data**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('jumlah-siswa-putus-sekolah-menurut-tingkat-tiap-provinsi-indonesia-sd-2023.csv')
data.head()
# Out:
#                 Provinsi  Tingkat - I  Tingkat - II  Tingkat - III  \
# 0   Prov. D.K.I. Jakarta          584            34             23
# 1       Prov. Jawa Barat         3633           498            231
# 2      Prov. Jawa Tengah         1538           182            102
# 3  Prov. D.I. Yogyakarta           31             2              2
# 4       Prov. Jawa Timur         1597           206            186
#
#    Tingkat - IV  Tingkat - V  Tingkat - VI  Jumlah  Status
# 0            24           15            15     695  Negeri
# 1           205          265           248    5080  Negeri
# 2           102          160            82    2166  Negeri
# 3             3            3             2      43  Negeri
# 4           172          216           202    2579  Negeri

# %% [markdown]
# **7.2.2 Mengubah data dalam bentuk numerik**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Provinsi       78 non-null     object
#  1   Tingkat - I    78 non-null     int64
#  2   Tingkat - II   78 non-null     int64
#  3   Tingkat - III  78 non-null     int64
#  4   Tingkat - IV   78 non-null     int64
#  5   Tingkat - V    78 non-null     int64
#  6   Tingkat - VI   78 non-null     int64
#  7   Jumlah         78 non-null     int64
#  8   Status         78 non-null     object
# dtypes: int64(7), object(2)
# memory usage: 5.6+ KB

# %%
from sklearn.preprocessing import LabelEncoder

# Menyalin dataframe
data_int = data.copy()

# Inisialisasi LabelEncoder
encoder = LabelEncoder()

# Membuat list dari nama kolom data kategori
categorical_data = ['Provinsi', 'Tingkat - I', 'Tingkat - II', 'Tingkat - III', 'Tingkat - IV', 'Tingkat - V', 'Tingkat - VI', 'Jumlah', 'Status']

# Mengubah setiap kolom kategori menjadi numerik
for kolom in categorical_data:
  data_int[kolom] = encoder.fit_transform(data[kolom])

# Menampilkan dataframe yang telah diubah
data_int.head()
# Out:
#    Provinsi  Tingkat - I  Tingkat - II  Tingkat - III  Tingkat - IV  \
# 0         6           59            23             18            18
# 1         9           68            59             50            50
# 2        10           65            55             44            45
# 3         5           11             1              2             3
# 4        11           66            57             49            49
#
#    Tingkat - V  Tingkat - VI  Jumlah  Status
# 0           12            13      51       0
# 1           58            52      72       0
# 2           50            37      69       0
# 3            3             2       7       0
# 4           55            51      70       0

# %%
import joblib

joblib.dump(encoder, 'encoder.pkl')
# Out:
# ['encoder.pkl']

# %% [markdown]
# **7.2.3 Menganlisis data kategori**

# %%
for kolom in categorical_data:
  print(kolom, data_int[kolom].unique())
# Out:
# Provinsi [ 6  9 10  5 11  1 38 36 30  8 37 19 12 14 13 15 35 33 32 34 20  2 22 23
#  24  4 21  3 17  7 18 25 31 16  0 29 28 27 26]
# Tingkat - I [59 68 65 11 66 56 67 49 55 52 63 51 58 45 43 44 33 53 61 48 46 17 60 62
#  24 38 41 64 32 29 39 23 42 26  7 25 37 18 28 50 35 10 47 14 54 12 36 15
#  21 16 20  4 27 13  1 31  2 57 19  8 34  3  6  5  0 40 30 22  9]
# Tingkat - II [23 59 55  1 57 43 58 40 49 42 53 32 48 29 26 36 37 54 45 35 12 44 56 33
#  13 34 50 20 27 14 25 31  7 11 30 41 38 24 39 16  0 46  4 52 10  3 19  6
#   8  9 17 28  2 51 21 15  5 18 47 22]
# Tingkat - III [18 50 44  2 49 36 51 29 42 30 48 32 41 27 20 25 19 45 38 31  7 46 26 14
#  33 35 28  9 23 16 39 43 22 24 15  3 40  5 37 17 13  4 11  8 10  1 12 34
#  21  0  6 47]
# Tingkat - IV [18 50 45  3 49 21 51 35 38 32 46 25 48 28 26 27 15 40 43 31 44 12 41 47
#  23 19 36 30 34 13 22 39 29 11  8 20 17  0 37  2 33  7 14  5 16 10  4  1
#   6 24  9 42]
# ...

# %%
for kolom in categorical_data:
  print(kolom, data[kolom].unique())
# Out:
# Provinsi ['Prov. D.K.I. Jakarta' 'Prov. Jawa Barat' 'Prov. Jawa Tengah'
#  'Prov. D.I. Yogyakarta' 'Prov. Jawa Timur' 'Prov. Aceh'
#  'Prov. Sumatera Utara' 'Prov. Sumatera Barat' 'Prov. Riau' 'Prov. Jambi'
#  'Prov. Sumatera Selatan' 'Prov. Lampung' 'Prov. Kalimantan Barat'
#  'Prov. Kalimantan Tengah' 'Prov. Kalimantan Selatan'
#  'Prov. Kalimantan Timur' 'Prov. Sulawesi Utara' 'Prov. Sulawesi Tengah'
#  'Prov. Sulawesi Selatan' 'Prov. Sulawesi Tenggara' 'Prov. Maluku'
#  'Prov. Bali' 'Prov. Nusa Tenggara Barat' 'Prov. Nusa Tenggara Timur'
#  'Prov. Papua' 'Prov. Bengkulu' 'Prov. Maluku Utara' 'Prov. Banten'
#  'Prov. Kepulauan Bangka Belitung' 'Prov. Gorontalo'
#  'Prov. Kepulauan Riau' 'Prov. Papua Barat' 'Prov. Sulawesi Barat'
#  'Prov. Kalimantan Utara' 'Luar Negeri' 'Prov. Papua Tengah'
#  'Prov. Papua Selatan' 'Prov. Papua Pegunungan' 'Prov. Papua Barat Daya']
# Tingkat - I [ 584 3633 1538   31 1597  521 1806  371  509  436  973  417  536  300
# ...

# %% [markdown]
# **7.2.4 Menganalisis Matriks Korelasi**

# %%
# Menampilkan matriks korelasi antar kolom
data_int.corr()
# Out:
#                    Provinsi  Tingkat - I  Tingkat - II  Tingkat - III  \
# Provinsi       1.000000e+00     0.121328      0.263216       0.262489
# Tingkat - I    1.213278e-01     1.000000      0.893639       0.886588
# Tingkat - II   2.632162e-01     0.893639      1.000000       0.942968
# Tingkat - III  2.624892e-01     0.886588      0.942968       1.000000
# Tingkat - IV   2.231377e-01     0.880362      0.911409       0.929557
# Tingkat - V    2.863587e-01     0.828050      0.876861       0.912119
# Tingkat - VI   3.104712e-01     0.808098      0.897521       0.922289
# Jumlah         2.147013e-01     0.965507      0.949147       0.951109
# Status        -3.439960e-17    -0.607673     -0.560009      -0.585406
#
#                Tingkat - IV  Tingkat - V  Tingkat - VI    Jumlah        Status
# Provinsi           0.223138     0.286359      0.310471  0.214701 -3.439960e-17
# Tingkat - I        0.880362     0.828050      0.808098  0.965507 -6.076727e-01
# ...

# %%
plt.figure(figsize=(8,4))
plt.title('Korelasi Antar Kolom')
sns.heatmap(data_int.corr(), annot=True, linewidth=3)
plt.show()

# %% [markdown]
# **7.2.5 Distribusi Data**

# %%
def distribusi():
  fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(10, 8))
  plt.suptitle('Distribusi Data', fontsize=24)

  def kolom_generator():
    for kolom in data_int.select_dtypes(include=np.number):
      yield kolom
  kolom = kolom_generator()

  for i in range(0, 2):
    for j in range(0, 3):
      k = next(kolom)
      data_int[k].plot(kind='hist', ax=axes[i, j])
      axes[i, j].set_xlabel(k)

plt.show()
distribusi()

# %% [markdown]
# **7.2.6 Pemisahan Data**

# %%
# Memisahkan data

data = data_int.drop('Jumlah', axis=1)
target = data_int['Jumlah']

# Memisahkan data untuk latihan dan tes
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data, target, test_size=0.2)

print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (62, 8) (62,)
# (16, 8) (16,)

# %% [markdown]
# **7.2.7 Membuat Machine Learning Model**

# %%
# Menggunakan linear SVC
from sklearn.svm import SVC

# Membuat objek nama model untuk memanggil SVC()
model = SVC(gamma='scale')

# %% [markdown]
# **7.2.8 Melatih Machine Learning Model**

# %%
# Melatih model dengan data pelatihan (x_train dan y_train)
model.fit(x_train, y_train)
# Out:
# SVC()

# %%
# Membuat prediksi dengan data uji (x_test)
prediction = model.predict(x_test)

# Membuat visualisasi matplotlib
plt.figure(figsize=(8, 6))
plt.scatter(y_test, prediction)
plt.xlabel('Negeri')
plt.ylabel('Swasta')
plt.title('Status Wilayah yang paling banyak tidak lulus atau putus sekolah')
plt.show()

# %% [markdown]
# **7.2.10 Analisa Confusion Matriks**

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Membuat confusion matrix
def display_conf(y_test,prediction):
    sns.heatmap(confusion_matrix(y_test, prediction), annot=True, linewidth=3, cbar=False)
    plt.title('Confusion Matriks')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

display_conf(y_test, prediction)

# %% [markdown]
# **7.2.10 Analisa eror matriks**

# %%
from sklearn.metrics import r2_score, classification_report

print(f'R2 Score : {r2_score(y_test, prediction)}')
print('Classification_report :')
print(classification_report(y_test, prediction, zero_division=0))
# Out:
# R2 Score : 0.7945740587404413
# Classification_report :
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       1.0
#            4       0.00      0.00      0.00       1.0
#            7       0.00      0.00      0.00       0.0
#           12       0.00      0.00      0.00       1.0
#           17       0.00      0.00      0.00       1.0
#           18       0.00      0.00      0.00       1.0
#           27       0.00      0.00      0.00       1.0
#           30       0.00      0.00      0.00       1.0
#           33       0.00      0.00      0.00       1.0
#           36       0.00      0.00      0.00       1.0
#           37       0.00      0.00      0.00       1.0
#           42       0.00      0.00      0.00       0.0
#           49       0.00      0.00      0.00       1.0
#           50       0.00      0.00      0.00       1.0
#           52       0.00      0.00      0.00       1.0
# ...

# %% [markdown]
# **7.2.11 Meningkatkan Model**

# %%
# Menggunakan GridSarchCV untuk menemukan model dengan parameter terbaik

from sklearn.model_selection import GridSearchCV
# Import StratifiedKFold untuk kontrol manual atas validasi silang
from sklearn.model_selection import StratifiedKFold

# Hyperparameter model SVC
param_grid = {'C':[0.01, 0.1, 1, 10, 100],
              'gamma':[100, 10, 1, 0.1, 0.01]}

# Buat objek StratifiedKFold dengan n_splits yang lebih rendah
# Pastikan n_splits kurang dari atau sama dengan jumlah minimum sampel di kelas mana pun
n_splits = min(5, y_train.value_counts().min())

# Ubah n_splits menjadi minimal 2 jika kurang dari 2
n_splits = max(2, n_splits)

# Membuat model terbaik dari semua kemungkinan kombinasi
best_model = GridSearchCV(SVC(), param_grid, cv=n_splits, refit=True)

# Melatih model terbaik
best_model.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# GridSearchCV(cv=2, estimator=SVC(),
#              param_grid={'C': [0.01, 0.1, 1, 10, 100],
#                          'gamma': [100, 10, 1, 0.1, 0.01]})

# %%
# Model dengan parameter terbaik
best_model.best_estimator_
# Out:
# SVC(C=1, gamma=0.01)

# %%
# Membuat prediksi dengan model yang telah ditingkatkan
prediction = best_model.predict(x_test)

# Menampilkan confusion matriks pada prediksi yang baru
display_conf(y_test, prediction)

# %%
print(f'R2 Score : {r2_score(y_test, prediction)}')
print('Classification_report :')
print(classification_report(y_test, prediction, zero_division=0))
# Out:
# R2 Score : 0.5476888607471628
# Classification_report :
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       1.0
#            4       0.00      0.00      0.00       1.0
#            7       0.00      0.00      0.00       0.0
#           12       0.00      0.00      0.00       1.0
#           17       0.00      0.00      0.00       1.0
#           18       0.00      0.00      0.00       1.0
#           27       0.00      0.00      0.00       1.0
#           30       0.00      0.00      0.00       1.0
#           33       0.00      0.00      0.00       1.0
#           36       0.00      0.00      0.00       1.0
#           37       0.00      0.00      0.00       1.0
#           42       0.00      0.00      0.00       0.0
#           49       0.00      0.00      0.00       1.0
#           50       0.00      0.00      0.00       1.0
#           52       0.00      0.00      0.00       1.0
# ...

# %% [markdown]
# **7.2.12 Mengulangi semua proses**
#
# Dengan mengulangi semua proses yang dimaksud adalah melakukan running ulang setiap cell code

# %% [markdown]
# **7.2.13 Menyimpan Machine Learning Model**

# %%
import pickle

# Menyimpan model menjadi file.pkl
with open('ML_Pendidikan.pkl', 'wb') as file:
  pickle.dump(best_model,file)

# %%
# Membuat model dalam file.pkl
with open('ML_Pendidikan.pkl', 'rb') as file:
  model = pickle.load(file)

# %%
# Model dengan parameter
best_model.best_estimator_
# Out:
# SVC(C=1, gamma=0.01)

# %%
def self_prediction():
    try:
        # Input pengguna dan konversi ke tipe data numerik
        provinsi = int(input('Provinsi (dalam angka): '))
        tingkat_i = int(input('Tingkat - I: '))
        tingkat_ii = int(input('Tingkat - II: '))
        tingkat_iii = int(input('Tingkat - III: '))
        tingkat_iv = int(input('Tingkat - IV: '))
        tingkat_v = int(input('Tingkat - V: '))
        tingkat_vi = int(input('Tingkat - VI: '))
        status = int(input('Status (0 untuk Negeri/1 untuk Swasta): '))

        # Membentuk data baru berbentuk DataFrame
        new_data = pd.DataFrame([{
            "Provinsi": provinsi,
            "Tingkat - I": tingkat_i,
            "Tingkat - II": tingkat_ii,
            "Tingkat - III": tingkat_iii,
            "Tingkat - IV": tingkat_iv,
            "Tingkat - V": tingkat_v,
            "Tingkat - VI": tingkat_vi,
            "Status": status
        }])

        # Prediksi menggunakan model yang telah dilatih
        pred_jumlah = best_model.predict(new_data)[0]
        print(f"\nPrediksi Jumlah Siswa: {pred_jumlah:.2f}")

    except ValueError:
        print('Error: Pastikan semua input berupa angka.')
    except Exception as e:
        print('Terjadi kesalahan:', e)

# Panggil fungsi prediksi
self_prediction()
# Out:
# Provinsi (dalam angka): 2
# Tingkat - I: 200
# Tingkat - II: 100
# Tingkat - III: 50
# Tingkat - IV: 35
# Tingkat - V: 20
# Tingkat - VI: 15
# Status (0 untuk Negeri/1 untuk Swasta): 1
#
# Prediksi Jumlah Siswa: 42.00
